# %%
from Repositories.Members import IReadableMemberList
import __init__
from abc import ABCMeta, abstractmethod
from typing import Optional, Tuple, List
from result import Result, Err, Ok

from Domains.Members import *
from Repositories.Members import *
from Builders.Members import *
from uuid import UUID

import pymysql

from icecream import ic

# %%
from Repositories.Members.IReadableMemberList import IReadableMemberList
import __init__
from abc import ABCMeta, abstractmethod
from typing import Optional, Tuple, List
from result import Result, Err, Ok

from Domains.Members import *
from Repositories.Members import *
from Builders.Members import *
from uuid import UUID

import pymysql

from icecream import ic


class MySqlGetMember(IReadableMemberList):
    def __init__(self, name_padding: str = "log_"):
        self.name_padding = name_padding

    def connect(self):
        from get_config_data import get_mysql_dict

        sql_config = get_mysql_dict()
        return pymysql.connect(
            host=sql_config["host"],
            user=sql_config["user"],
            password=sql_config["password"],
            db=sql_config["database"],
            charset=sql_config["charset"],
        )

    def get_padding_name(self, name: str) -> str:
        return f"{self.name_padding}{name}"

    def get_members(
        self,
        page=0,
        size=10,
    ) -> Result[Tuple[int, List[Member]], str]:
        
        connection = self.connect()
        user_table_name = self.get_padding_name("user")
        #여기부터 수정 중
        try:
            # 커서 생성
            with connection.cursor() as cursor:
                offset = page * size
                query = f"""
SELECT id, account, role
FROM {user_table_name}
ORDER BY seq DESC
LIMIT %s, %s
"""                
                cursor.execute(query, (offset, size))
                result = cursor.fetchall()

                users = []
                for row in result:
                    id, account, role = row
                    member = Member(
                        id=MemberIDBuilder().set_uuid(id).build(),
                        account=account,  # Member 클래스에 account 인자가 있는지 확인
                        role=role
                    )
                    users.append(member)

                cursor.execute(f"SELECT COUNT(*) FROM {user_table_name}")
                total_count = cursor.fetchone()[0]

                connection.commit()

                return Ok((total_count, users))
            # 여기 아래로 수정 안해도됨
        except Exception as e:
            print(e)
            connection.close()  
            return Err(str(e))

# %%
# 테스트 코드
my_sql_get_member = MySqlGetMember()
result = my_sql_get_member.get_members(page=0, size=2)

if result.is_ok():
    total_count, users = result.unwrap()
    print(f"Total Count: {total_count}")
    for user in users:
        print(f"ID: {user.id}, Account: {user.account}, Role: {user.role}")
else:
    print(f"Error: {result.unwrap_err()}")
# Out:
# Total Count: 4
# ID: MemberID(uuid=UUID('73b3bdb3-f936-42ce-aa03-e3e416f51a1d'), sequence=-1), Account: zxcv, Role: buyer
# ID: MemberID(uuid=UUID('86aa2a38-a79f-4dd1-9bce-9ac9ffe6119e'), sequence=-1), Account: asdf, Role: buyer

# %%
import __init__
from typing import List

from get_config_data import get_db_padding
from result import Result, Ok, Err
from Domains.Members import MemberID
from Domains.Products import ProductID, Product
from Domains.Comments import Comment, CommentID
from datetime import datetime
from icecream import ic
import pandas as pd


def init_product():
    from Storages.Products import MySqlGetProduct, MySqlSaveProduct
    from Builders.Products import ProductIDBuilder
    from init_data import member_list, product_list

    product_list.clear()
    create = MySqlSaveProduct(get_db_padding())

    id = ProductIDBuilder().set_uuid().set_seqence(1).build()

    # CSV 파일 경로
    csv_path = 'docs/init_product_list.csv'
    # CSV 파일을 DataFrame으로 읽어오기
    df = pd.read_csv(csv_path)

    for _, row in df.iterrows():
        id = ProductIDBuilder().set_uuid().set_seqence(1).build()

        match create.save_product(
            Product(
                id=id,
                seller_id=member_list[0],
                name=row['상품 이름'],               # 두번째 col
                img_path=row['상품 이미지'],       # 첫번째 col
                price=str(row['상품 가격']),        # 세번째 col
                description=row['상품 설명'], # 네번째 col
                register_day=datetime.now(),
            )
        ):
            case Ok(product):
                product_list.append(product)
            case a:
                assert False, f"Fail Create Member:{a}"
# 테스트 함수 호출
init_product()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 48
#      46                 assert False, f"Fail Create Member:{a}"
#      47 # 테스트 함수 호출
# ---> 48 init_product()
#
# Cell In[5], line 35, in init_product()
#      29 for _, row in df.iterrows():
#      30     id = ProductIDBuilder().set_uuid().set_seqence(1).build()
#      32     match create.save_product(
#      33         Product(
#      34             id=id,
# ---> 35             seller_id=member_list[0],
#      36             name=row['상품 이름'],               # 두번째 col
#      37             img_path=row['상품 이미지'],       # 첫번째 col
#      38             price=str(row['상품 가격']),        # 세번째 col
#      39             description=row['상품 설명'], # 네번째 col
#      40             register_day=datetime.now(),
#      41         )
#      42     ):
#      43         case Ok(product):
# ...
